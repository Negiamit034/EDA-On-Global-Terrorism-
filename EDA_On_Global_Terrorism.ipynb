# %% [markdown]
# # **Project Name**    - Exploratory Data Analysis (EDA) on Global Terrorism

# %% [markdown]
# ![dataset-card.png](data:image/png;base64,...)

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Name**            - Amit Negi

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# **Project Summary: Exploring Global Terrorism Database for Insights and Recommendations**
#
# The project embarked on a comprehensive analysis of the Global Terrorism Database (GTD), a repository of over 180,000 terrorist incidents spanning four decades from 1970 to 2017. This open-source database, managed by the National Consortium for the Study of Terrorism and Responses to Terrorism (START) at the University of Maryland, offers a wealth of information on terrorism's patterns, impacts, and dynamics. The analysis was guided by a set of business objectives, aiming to extract insights that would contribute to informed decision-making, enhanced security measures, and public awareness efforts.
#
# The project involved a series of systematic steps, including importing important libraries, loading and understanding the dataset's structure, identifying key variables, and addressing data quality concerns such as duplicate values and missing data. Data wrangling techniques were employed to refine the dataset, followed by exploratory data visualization using line charts, pie charts, pair plots, and horizontal bar charts to uncover trends, correlations, and distributions.
#
# Key insights and findings emerged from the analysis:
#
# - Temporal Trends: An exploration of temporal trends revealed cyclical patterns, with a surge in incidents around 2014 possibly linked to geopolitical events. Recent years displayed a decline, potentially indicating the effectiveness of counterterrorism measures.
#
# - Geographical Patterns: The analysis highlighted regions like the Middle East & North Africa and South Asia as hotspots for terrorist incidents, underscoring the need for targeted security measures.
#
# - Attack Tactics and Targets: Insights into prevalent attack tactics (e.g., bombings/explosions) and target types (e.g., private citizens, military) provided a nuanced understanding of terrorists' methods and motivations.
#
# - Success Rates and Correlations: The analysis revealed a relatively high success rate of attacks and identified variables with strong correlations, shedding light on underlying dynamics.
#
# Based on these insights, a set of strategic recommendations was devised to achieve the business objectives:
#
# - **Strategic Security Measures**: Deploy enhanced security measures in high-incident regions, addressing prevalent attack tactics and vulnerabilities in target types.
#
# - **Global Collaboration**: Foster collaboration among international organizations to counter regional and city-specific terrorism concentrations through information sharing and coordinated efforts.
#
# - **Targeted Counter-Radicalization**: Design tailored initiatives to counter radicalization efforts of active terrorist groups, discouraging individuals from joining their ranks.
#
# - **Public Awareness Campaigns**: Utilize insights to create impactful campaigns that educate the public about terrorism's complexities and the ongoing efforts to combat it.
#
# - **Policy Refinement**: Collaborate with policymakers to formulate evidence-based counterterrorism policies, considering vulnerabilities and refining strategies.
#
# - **Continuous Evaluation and Adaptation**: Establish mechanisms to continuously evaluate and adapt counterterrorism efforts, leveraging feedback for strategy refinement.
#
# This project reflects the power of data analysis in uncovering hidden insights and providing practical recommendations to address complex challenges. By utilizing the insights derived from the GTD, this project equips stakeholders with valuable tools to foster international collaboration, enhance security measures, and create informed policies to counter terrorism's multifaceted nature.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/Negiamit034

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# 1.  What are the temporal trends in global terrorism over the last four decades?
# 2.  Which region have experienced the highest frequency of terrorist attacks?
# 3.  Which countries have experienced the highest frequency of
#     terrorist attacks?
# 4.  Which city have experienced the highest frequency of
#     terrorist attacks?
# 5.  What are the most common types of terrorist tactics employed during the
#     studied period?
# 6.  Are there any seasonal or cyclical patterns in terrorist activity?
# 7.  How have terrorist attack patterns evolved over time in different regions?
# 8.  Analyze the occurrence of different attack types across various regions to uncover patterns in the geographical distribution of terrorist tactics?
# 9.  What are the primary target types of terrorist attacks recorded?
# 10.  What are the most frequent weapons used in terrorist attacks?
# 11. Is there a correlation between the target type and the attack type?
# 12. To identify and analyze the terrorist group with the highest contribution in terrorist?
# 13. What is the proportion of successful terrorist attacks compared to failed ones using the 'success' variable?

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Business objectives for the Global Terrorism Database (GTD) analysis:
#
# 1. Develop Actionable Insights: Extract valuable insights from the GTD to provide actionable recommendations for governments, security agencies, and organizations in their efforts to counter and prevent terrorism.
#
# 2. Enhance Security Measures: Identify vulnerable regions or areas prone to terrorist attacks based on the analysis, enabling the implementation of targeted security measures to minimize the risk of future incidents.
#
# 3. Support Policy and Decision-Making: Provide evidence-based data and analysis to aid policymakers in formulating effective counterterrorism policies and strategies.
#
# 4. Improve International Cooperation: Facilitate information sharing and collaboration among countries and international organizations to combat terrorism on a global scale.
#
# 5. Enhance Public Awareness: Raise public awareness about the nature and complexities of terrorism by disseminating key findings and insights from the analysis.
#
# 6. Strengthen Emergency Preparedness: Help emergency response teams and organizations in preparing for potential terrorist incidents by understanding historical attack patterns and trends.
#
# 7. Combat Radicalization: Utilize the analysis to design targeted initiatives to counter radicalization efforts and prevent individuals from joining terrorist groups.
#
# 8. Assess the Impact of Counterterrorism Efforts: Evaluate the effectiveness of past counterterrorism measures and initiatives, identifying areas of success and areas that may require further attention.
#
# 9. Foster International Collaboration in Research: Contribute to the global research community by sharing valuable analysis and insights from the GTD, fostering international collaboration in the field of terrorism studies.
#
# 10. Promote Data-Driven Decision Making: Encourage the use of data-driven decision-making processes within governments, organizations, and institutions working on security and counterterrorism efforts.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# Project Overview:
#
# The main goal of this project is to perform an extensive Exploratory Data Analysis (EDA) on the Global Terrorism Database (GTD) while adhering to specific guidelines to ensure high-quality analysis and code. The project focuses on producing well-structured, formatted, and commented code, with additional emphasis on exceptional elements such as Exception Handling, Production Grade Code, and Deployment Readiness. Students who achieve these criteria will be rewarded with additional credits, giving them an advantage during Star Student selection.
#
# Guidelines:
#
# 1. Well-structured, Formatted, and Commented Code:
#    - Emphasize the importance of maintaining a well-structured codebase with appropriate formatting and commenting.
#    - Clear comments should accompany every logic and function, ensuring easy understanding for all stakeholders.
#
# 2. Exception Handling, Production Grade Code, and Deployment Readiness:
#    - Encourage the implementation of robust exception handling in the code to gracefully handle errors.
#    - Aim to create production-grade code following industry best practices, suitable for real-world deployment.
#    - Ensure the entire Jupyter notebook (.ipynb) is executable without encountering any errors, making it deployment-ready.
#
# 3. Chart Visualization and Insights:
#    - Create a minimum of 20 logical and meaningful charts based on "UBM" rule (Univariate, Bivariate, Multivariate Analysis).
#    - For each chart, provide clear justifications for the selection of the specific visualization.
#    - Highlight the insights gained from each chart and assess their potential positive business impact.
#    - Consider and justify any insights that may lead to negative growth, providing specific reasons for their implications.
#
# 4. Foster Data-Driven Decision Making:
#    - Stress the significance of data-driven decision-making in the fight against terrorism.
#    - Provide evidence-based insights that can guide governments, security agencies, and organizations in formulating effective counterterrorism policies and strategies.
#
# By following these guidelines, the project aims to contribute significantly to the global understanding of terrorism. The well-structured code and insightful analysis will be invaluable resources for stakeholders working towards creating a safer and more secure world. Students who excel in meeting the specified criteria will be recognized for their exceptional effort, skills, and potential positive impact on counterterrorism efforts.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Important Libraries
import numpy as np                    #import numpy for numerical computation
import pandas as pd                   #import pandas for data manipulation
import matplotlib.pyplot as plt       #for data visualisation
import seaborn as sns                 #for data visualisation

# %% [markdown]
# ### Dataset Loading

# %%
from google.colab import drive        #Mount the drive to connect with file
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Loading the Dataset
Gterrorism_df=pd.read_csv('/content/drive/MyDrive/EDA on Global Terrorism/Global Terrorism Data (1).csv', encoding='latin-1')    #creating dataframe reading with 'latin-1' encoding
# Out:
# <ipython-input-3-e6e5309ced2f>:2: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   Gterrorism_df=pd.read_csv('/content/drive/MyDrive/EDA on Global Terrorism/Global Terrorism Data (1).csv', encoding='latin-1')    #creating dataframe reading with 'latin-1' encoding

# %% [markdown]
# ### Dataset First View

# %%
Gterrorism_df #Dataset First Look
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country         country_txt  region  ... addnotes  \
# ...

# %%
Gterrorism_df.head()       #top five rows
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
Gterrorism_df.tail()      #Bottom five rows
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ... addnotes  \
# 181686      182      Somalia      11  ...      NaN
# 181687      200        Syria      10  ...      NaN
# 181688      160  Philippines       5  ...      NaN
# 181689       92        India       6  ...      NaN
# 181690      160  Philippines       5  ...      NaN
#
#                                                    scite1  \
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
Gterrorism_df.shape      #Dataset Rows & Columns count
# Out:
# (181691, 135)

# %% [markdown]
# ### Dataset Information

# %%
Gterrorism_df.info()       #Dataset Info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %% [markdown]
# #### Duplicate Values

# %%
Duplicate_values=Gterrorism_df[Gterrorism_df.duplicated()].sum()  #Dataset Duplicate Value Count

# %%
Duplicate_values[:51]                                             #Duplicate values count for the first 50 columns
# Out:
# eventid             0.0
# iyear               0.0
# imonth              0.0
# iday                0.0
# approxdate          0.0
# extended            0.0
# resolution          0.0
# country             0.0
# country_txt         0.0
# region              0.0
# region_txt          0.0
# provstate           0.0
# city                0.0
# latitude            0.0
# longitude           0.0
# specificity         0.0
# vicinity            0.0
# location            0.0
# summary             0.0
# crit1               0.0
# crit2               0.0
# crit3               0.0
# doubtterr           0.0
# alternative         0.0
# alternative_txt     0.0
# multiple            0.0
# success             0.0
# suicide             0.0
# attacktype1         0.0
# attacktype1_txt     0.0
# attacktype2         0.0
# attacktype2_txt     0.0
# attacktype3         0.0
# attacktype3_txt     0.0
# targtype1           0.0
# targtype1_txt       0.0
# targsubtype1        0.0
# targsubtype1_txt    0.0
# ...

# %%
Duplicate_values[51:101]                                         #duplicate values count from the column 51 to 100
# Out:
# targtype3_txt       0.0
# targsubtype3        0.0
# targsubtype3_txt    0.0
# corp3               0.0
# target3             0.0
# natlty3             0.0
# natlty3_txt         0.0
# gname               0.0
# gsubname            0.0
# gname2              0.0
# gsubname2           0.0
# gname3              0.0
# gsubname3           0.0
# motive              0.0
# guncertain1         0.0
# guncertain2         0.0
# guncertain3         0.0
# individual          0.0
# nperps              0.0
# nperpcap            0.0
# claimed             0.0
# claimmode           0.0
# claimmode_txt       0.0
# claim2              0.0
# claimmode2          0.0
# claimmode2_txt      0.0
# claim3              0.0
# claimmode3          0.0
# claimmode3_txt      0.0
# compclaim           0.0
# weaptype1           0.0
# weaptype1_txt       0.0
# weapsubtype1        0.0
# weapsubtype1_txt    0.0
# weaptype2           0.0
# weaptype2_txt       0.0
# weapsubtype2        0.0
# weapsubtype2_txt    0.0
# ...

# %%
Duplicate_values[101:]                                                  #duplicate values count for the rest columns
# Out:
# nwound                0.0
# nwoundus              0.0
# nwoundte              0.0
# property              0.0
# propextent            0.0
# propextent_txt        0.0
# propvalue             0.0
# propcomment           0.0
# ishostkid             0.0
# nhostkid              0.0
# nhostkidus            0.0
# nhours                0.0
# ndays                 0.0
# divert                0.0
# kidhijcountry         0.0
# ransom                0.0
# ransomamt             0.0
# ransomamtus           0.0
# ransompaid            0.0
# ransompaidus          0.0
# ransomnote            0.0
# hostkidoutcome        0.0
# hostkidoutcome_txt    0.0
# nreleased             0.0
# addnotes              0.0
# scite1                0.0
# scite2                0.0
# scite3                0.0
# dbsource              0.0
# INT_LOG               0.0
# INT_IDEO              0.0
# INT_MISC              0.0
# INT_ANY               0.0
# related               0.0
# dtype: float64

# %% [markdown]
# #### Missing Values/Null Values

# %%
Null_values=Gterrorism_df.isna().sum()     #Missing Values/Null Values Count

# %%
Null_values[:51]                           #Null values count for the first 50 columns
# Out:
# eventid                  0
# iyear                    0
# imonth                   0
# iday                     0
# approxdate          172452
# extended                 0
# resolution          179471
# country                  0
# country_txt              0
# region                   0
# region_txt               0
# provstate              421
# city                   434
# latitude              4556
# longitude             4557
# specificity              6
# vicinity                 0
# location            126196
# summary              66129
# crit1                    0
# crit2                    0
# crit3                    0
# doubtterr                1
# alternative         152680
# alternative_txt     152680
# multiple                 1
# success                  0
# suicide                  0
# attacktype1              0
# attacktype1_txt          0
# attacktype2         175377
# attacktype2_txt     175377
# attacktype3         181263
# attacktype3_txt     181263
# ...

# %%
Null_values[51:101]                           #Null values count from column 51 to 100
# Out:
# targtype3_txt       180515
# targsubtype3        180594
# targsubtype3_txt    180594
# corp3               180665
# target3             180516
# natlty3             180544
# natlty3_txt         180544
# gname                    0
# gsubname            175801
# gname2              179678
# gsubname2           181531
# gname3              181367
# gsubname3           181671
# motive              131130
# guncertain1            380
# guncertain2         179736
# guncertain3         181371
# individual               0
# nperps               71115
# nperpcap             69489
# claimed              66120
# claimmode           162608
# claimmode_txt       162608
# claim2              179801
# claimmode2          181075
# claimmode2_txt      181075
# claim3              181373
# claimmode3          181558
# claimmode3_txt      181558
# compclaim           176852
# weaptype1                0
# weaptype1_txt            0
# weapsubtype1         20768
# weapsubtype1_txt     20768
# ...

# %%
Null_values[101:]                           #Null values count for the rest columns
# Out:
# nwound                 16311
# nwoundus               64702
# nwoundte               69143
# property                   0
# propextent            117626
# propextent_txt        117626
# propvalue             142702
# propcomment           123732
# ishostkid                178
# nhostkid              168119
# nhostkidus            168174
# nhours                177628
# ndays                 173567
# divert                181367
# kidhijcountry         178386
# ransom                104310
# ransomamt             180341
# ransomamtus           181128
# ransompaid            180917
# ransompaidus          181139
# ransomnote            181177
# hostkidoutcome        170700
# hostkidoutcome_txt    170700
# nreleased             171291
# addnotes              153402
# scite1                 66191
# scite2                104758
# scite3                138175
# dbsource                   0
# INT_LOG                    0
# INT_IDEO                   0
# INT_MISC                   0
# ...

# %%
# Plot the heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(Gterrorism_df.isna())
plt.title('Null Values Heatmap')
plt.show()      #Visualizing the missing values

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The dataset named Gterrorism_df contains 181,691 rows and 135 columns. It represents global terrorism data. The data types in the columns include float64, int64, and object. The dataset is relatively large, consuming around 187.1 MB of memory. There are no duplicate values, but several columns have a significant number of null values. Further analysis and data preprocessing may be necessary to handle the null values effectively.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
Columns_name=Gterrorism_df.columns                  #Dataset Columns
Columns_name
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
Columns_name[:51]                                   #First 50 Columns Name
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'specificity', 'vicinity',
#        'location', 'summary', 'crit1', 'crit2', 'crit3', 'doubtterr',
#        'alternative', 'alternative_txt', 'multiple', 'success', 'suicide',
#        'attacktype1', 'attacktype1_txt', 'attacktype2', 'attacktype2_txt',
#        'attacktype3', 'attacktype3_txt', 'targtype1', 'targtype1_txt',
#        'targsubtype1', 'targsubtype1_txt', 'corp1', 'target1', 'natlty1',
#        'natlty1_txt', 'targtype2', 'targtype2_txt', 'targsubtype2',
#        'targsubtype2_txt', 'corp2', 'target2', 'natlty2', 'natlty2_txt',
#        'targtype3'],
#       dtype='object')

# %%
Columns_name[51:101]                                   #From column 51 to 100 columns name
# Out:
# Index(['targtype3_txt', 'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3',
#        'natlty3', 'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2',
#        'gname3', 'gsubname3', 'motive', 'guncertain1', 'guncertain2',
#        'guncertain3', 'individual', 'nperps', 'nperpcap', 'claimed',
#        'claimmode', 'claimmode_txt', 'claim2', 'claimmode2', 'claimmode2_txt',
#        'claim3', 'claimmode3', 'claimmode3_txt', 'compclaim', 'weaptype1',
#        'weaptype1_txt', 'weapsubtype1', 'weapsubtype1_txt', 'weaptype2',
#        'weaptype2_txt', 'weapsubtype2', 'weapsubtype2_txt', 'weaptype3',
#        'weaptype3_txt', 'weapsubtype3', 'weapsubtype3_txt', 'weaptype4',
#        'weaptype4_txt', 'weapsubtype4', 'weapsubtype4_txt', 'weapdetail',
#        'nkill', 'nkillus', 'nkillter'],
#       dtype='object')

# %%
Columns_name[101:]                                   #Rest of the columns name
# Out:
# Index(['nwound', 'nwoundus', 'nwoundte', 'property', 'propextent',
#        'propextent_txt', 'propvalue', 'propcomment', 'ishostkid', 'nhostkid',
#        'nhostkidus', 'nhours', 'ndays', 'divert', 'kidhijcountry', 'ransom',
#        'ransomamt', 'ransomamtus', 'ransompaid', 'ransompaidus', 'ransomnote',
#        'hostkidoutcome', 'hostkidoutcome_txt', 'nreleased', 'addnotes',
#        'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG', 'INT_IDEO',
#        'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object')

# %%
Gterrorism_df.describe(include='all') #Dataset Describe
# Out:
#              eventid          iyear         imonth           iday  \
# count   1.816910e+05  181691.000000  181691.000000  181691.000000
# unique           NaN            NaN            NaN            NaN
# top              NaN            NaN            NaN            NaN
# freq             NaN            NaN            NaN            NaN
# mean    2.002705e+11    2002.638997       6.467277      15.505644
# std     1.325957e+09      13.259430       3.388303       8.814045
# min     1.970000e+11    1970.000000       0.000000       0.000000
# 25%     1.991021e+11    1991.000000       4.000000       8.000000
# 50%     2.009022e+11    2009.000000       6.000000      15.000000
# 75%     2.014081e+11    2014.000000       9.000000      23.000000
# max     2.017123e+11    2017.000000      12.000000      31.000000
#
#                    approxdate       extended resolution        country  \
# count                    9239  181691.000000       2220  181691.000000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# A short description of some important variables in the Gterrorism_df dataset:
#
# 1. eventid: Unique identifier for each terrorism event.
# 2. iyear: Year of the incident.
# 3. imonth: Month of the incident.
# 4. iday: Day of the incident.
# 5. country_txt: Name of the country where the incident occurred.
# 6. region_txt: Name of the region where the incident occurred.
# 7. city: Name of the city where the incident occurred.
# 8. latitude: Latitude coordinate of the incident location.
# 9. longitude: Longitude coordinate of the incident location.
# 10. gname: Name of the terrorist group responsible for the incident.
# 11. nkill: Number of people killed in the incident.
# 12. nwound: Number of people wounded in the incident.
# 13. weaptype1_txt: Type of weapon used in the incident.
# 14. targtype1_txt: Type of target/victim of the attack.
# 15. 'dbsource': Source of the data or database from which the attack information was obtained.
# 16. 'ransom': Indicates if a ransom was demanded or paid during a kidnapping-related attack.
# 17. 'individual': Indicates if the attack was carried out by an individual acting alone (1) or a group (0).
# 18. 'success': Indicates the overall success (1) or failure (0) of the terrorist attack.
# 19. 'suicide': Indicates if the attack involved a suicide element (1) or not (0).
# 20. 'hostkidoutcome_txt': Outcome of a hostage situation during the attack.
# 21. 'ransomamt': Amount of ransom demanded or paid during a kidnapping-related attack.
# 22. 'ishostkid': Indicates if there were hostages taken during the terrorist attack (1) or not (0).
# 23. 'property': Indicates whether there was property damage during the terrorist attack (0 = no damage, 1 = property damage, -9 = unknown/missing data).
#
# Please note that this is not an exhaustive list of all the variables, but these are some of the key ones that provide essential information about each terrorism event in the dataset.

# %% [markdown]
# ### Check Unique Values for each variable.

# %% [markdown]
# **Note-As we can see in the dataset we have 135 columns, numerous contain null values and lack relevance. To streamline analysis, we focus on important columns and examine their unique values.**

# %%
Gterrorism_df['iyear'].unique()   #checking unique values
# Out:
# array([1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980,
#        1981, 1986, 1982, 1983, 1984, 1985, 1987, 1988, 1989, 1990, 1991,
#        1992, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003,
#        2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014,
#        2015, 2016, 2017])

# %%
Gterrorism_df['imonth'].unique()    #checking unique values
# Out:
# array([ 7,  0,  1,  2,  3,  4,  5,  6,  8,  9, 10, 11, 12])

# %%
Gterrorism_df['iday'].unique()      #checking unique values
# Out:
# array([ 2,  0,  1,  3,  6,  8,  9, 10, 11, 12, 13, 14, 15, 19, 20, 21, 22,
#        25, 26, 27, 28, 30, 31,  4,  7, 16, 17, 18, 23, 24,  5, 29])

# %%
Gterrorism_df['country_txt'].unique()      #checking unique values
# Out:
# array(['Dominican Republic', 'Mexico', 'Philippines', 'Greece', 'Japan',
#        'United States', 'Uruguay', 'Italy', 'East Germany (GDR)',
#        'Ethiopia', 'Guatemala', 'Venezuela', 'West Germany (FRG)',
#        'Switzerland', 'Jordan', 'Spain', 'Brazil', 'Egypt', 'Argentina',
#        'Lebanon', 'Ireland', 'Turkey', 'Paraguay', 'Iran',
#        'United Kingdom', 'Colombia', 'Bolivia', 'Nicaragua',
#        'Netherlands', 'Belgium', 'Canada', 'Australia', 'Pakistan',
#        'Zambia', 'Sweden', 'Costa Rica', 'South Yemen', 'Cambodia',
#        'Israel', 'Poland', 'Taiwan', 'Panama', 'Kuwait',
#        'West Bank and Gaza Strip', 'Austria', 'Czechoslovakia', 'India',
#        'France', 'South Vietnam', 'Brunei', 'Zaire',
#        "People's Republic of the Congo", 'Portugal', 'Algeria',
#        'El Salvador', 'Thailand', 'Haiti', 'Sudan', 'Morocco', 'Cyprus',
#        'Myanmar', 'Afghanistan', 'Peru', 'Chile', 'Honduras',
# ...

# %%
Gterrorism_df['region_txt'].unique()    #checking unique values
# Out:
# array(['Central America & Caribbean', 'North America', 'Southeast Asia',
#        'Western Europe', 'East Asia', 'South America', 'Eastern Europe',
#        'Sub-Saharan Africa', 'Middle East & North Africa',
#        'Australasia & Oceania', 'South Asia', 'Central Asia'],
#       dtype=object)

# %%
Gterrorism_df['provstate'].unique()     #checking unique values
# Out:
# array([nan, 'Federal', 'Tarlac', ..., 'Carlow', 'Western Lakes',
#        'Vidzeme'], dtype=object)

# %%
Gterrorism_df['city'].unique()           #checking unique values
# Out:
# array(['Santo Domingo', 'Mexico city', 'Unknown', ..., 'Hungrum',
#        'Ceelka Geelow', 'Kubentog'], dtype=object)

# %%
Gterrorism_df['success'].unique()         #checking unique values
# Out:
# array([1, 0])

# %%
Gterrorism_df['suicide'].unique()          #checking unique values
# Out:
# array([0, 1])

# %%
Gterrorism_df['attacktype1_txt'].unique()            #checking unique values
# Out:
# array(['Assassination', 'Hostage Taking (Kidnapping)',
#        'Bombing/Explosion', 'Facility/Infrastructure Attack',
#        'Armed Assault', 'Hijacking', 'Unknown', 'Unarmed Assault',
#        'Hostage Taking (Barricade Incident)'], dtype=object)

# %%
Gterrorism_df['targtype1_txt'].unique()               #checking unique values
# Out:
# array(['Private Citizens & Property', 'Government (Diplomatic)',
#        'Journalists & Media', 'Police', 'Utilities', 'Military',
#        'Government (General)', 'Airports & Aircraft', 'Business',
#        'Educational Institution', 'Violent Political Party',
#        'Religious Figures/Institutions', 'Unknown', 'Transportation',
#        'Tourists', 'NGO', 'Telecommunication', 'Food or Water Supply',
#        'Terrorists/Non-State Militia', 'Other', 'Maritime',
#        'Abortion Related'], dtype=object)

# %%
Gterrorism_df['gname'].unique()               #checking unique values
# Out:
# array(['MANO-D', '23rd of September Communist League', 'Unknown', ...,
#        'Fatoni Warriors', 'Minorities of Metropolitan Attacks',
#        'Baloch Republican Party'], dtype=object)

# %%
Gterrorism_df['nkill'].unique()               #checking unique values
# Out:
# array([1.000e+00, 0.000e+00,       nan, 7.000e+00, 4.700e+01, 2.000e+00,
#        3.600e+01, 5.000e+00, 3.000e+00, 4.000e+00, 2.500e+01, 1.500e+01,
#        2.600e+01, 8.000e+00, 8.100e+01, 6.000e+00, 9.000e+00, 1.600e+01,
#        3.000e+01, 3.100e+01, 1.200e+01, 2.100e+01, 1.400e+01, 8.800e+01,
#        1.100e+01, 1.000e+01, 2.700e+01, 1.800e+01, 2.200e+01, 1.900e+01,
#        9.200e+01, 1.300e+01, 7.300e+01, 1.000e+02, 4.200e+01, 4.300e+01,
#        1.700e+01, 9.800e+01, 4.220e+02, 4.800e+01, 3.400e+01, 5.400e+01,
#        5.000e+01, 3.500e+01, 2.000e+01, 4.100e+01, 3.700e+01, 2.800e+01,
#        4.000e+01, 3.200e+01, 8.500e+01, 2.300e+01, 3.000e+02, 6.000e+01,
#        2.400e+01, 5.800e+01, 7.000e+01, 8.700e+01, 4.500e+01, 3.800e+01,
#        2.900e+01, 7.400e+01, 8.300e+01, 9.000e+01, 6.600e+01, 8.000e+01,
#        6.700e+01, 5.100e+01, 3.900e+01, 1.140e+02, 1.240e+02, 7.600e+01,
#        3.300e+01, 7.500e+01, 5.700e+01, 6.200e+01, 4.600e+01, 5.600e+01,
# ...

# %%
Gterrorism_df['nwound'].unique()                     #checking unique values
# Out:
# array([0.000e+00,       nan, 1.000e+00, 2.000e+00, 7.000e+00, 9.000e+00,
#        1.700e+01, 5.000e+00, 3.000e+00, 1.000e+01, 1.200e+01, 2.000e+01,
#        4.000e+00, 1.100e+01, 2.700e+01, 1.300e+01, 1.900e+01, 1.300e+02,
#        5.600e+01, 2.400e+01, 6.000e+00, 7.200e+01, 2.380e+02, 5.500e+01,
#        1.500e+01, 8.000e+00, 1.800e+01, 5.000e+01, 3.400e+01, 1.400e+01,
#        7.000e+01, 1.020e+02, 4.100e+01, 4.800e+01, 3.600e+01, 2.500e+01,
#        8.100e+01, 5.400e+01, 5.300e+01, 1.000e+02, 4.500e+01, 3.300e+01,
#        4.000e+01, 6.200e+01, 7.400e+01, 2.200e+01, 3.100e+01, 1.600e+01,
#        3.000e+01, 2.850e+02, 2.300e+01, 4.200e+01, 4.300e+01, 7.600e+01,
#        4.400e+01, 5.200e+01, 4.600e+01, 4.900e+01, 1.600e+02, 3.700e+01,
#        2.100e+01, 6.000e+01, 7.800e+01, 2.600e+01, 2.800e+01, 3.900e+01,
#        3.800e+01, 3.500e+01, 3.200e+01, 8.000e+01, 4.700e+01, 1.880e+02,
#        2.150e+02, 8.500e+01, 7.500e+01, 1.610e+02, 9.000e+01, 3.000e+02,
# ...

# %%
Gterrorism_df['property'].unique()                 #checking unique values
# Out:
# array([ 0,  1, -9])

# %%
Gterrorism_df['hostkidoutcome_txt'].unique()                   #checking unique values
# Out:
# array([nan, 'Hostage(s) released by perpetrators', 'Successful Rescue',
#        'Hostage(s) killed (not during rescue attempt)',
#        'Hostage(s) escaped (not during rescue attempt)', 'Unknown',
#        'Combination', 'Attempted Rescue'], dtype=object)

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %% [markdown]
# **Removing Unecessary Columns**

# %% [markdown]
# **Note**-Following thorough data exploration, it became evident that the dataset contained extraneous columns and significant null value instances. To enhance data quality, a focused data wrangling effort was undertaken. Irrelevant columns were meticulously identified and pruned, streamlining the dataset. Simultaneously, columns with substantial null values, posing analytical limitations, were judiciously omitted. This meticulous process aimed to refine the dataset's composition, ensuring a robust foundation for subsequent analyses. By meticulously dropping unnecessary columns and addressing sizable null value occurrences, the dataset's integrity was heightened, propelling more accurate and insightful exploration.

# %%
Gterrorism_df.shape    #to know the column presennt in the dataframe
# Out:
# (181691, 135)

# %%
Gterrorism_df.drop(columns=['location', 'summary', 'alternative', 'attacktype2','targtype1',
    'attacktype2_txt', 'attacktype3', 'attacktype3_txt', 'targsubtype1',
    'corp1', 'target1', 'natlty1', 'targtype2', 'targtype2_txt',
    'targsubtype2', 'targsubtype2_txt', 'corp2', 'target2', 'natlty2', 'natlty2_txt',
    'targtype3', 'targtype3_txt', 'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3',
    'natlty3', 'natlty3_txt', 'gsubname', 'gname2', 'gsubname2', 'gname3', 'gsubname3',
    'motive', 'claimmode', 'claimmode_txt', 'claim2', 'claimmode2', 'claimmode2_txt',
    'claim3', 'claimmode3', 'claimmode3_txt', 'compclaim', 'weapsubtype1',
    'weaptype2', 'weaptype2_txt', 'weapsubtype2', 'weapsubtype2_txt', 'weaptype3', 'weaptype3_txt',
    'weapsubtype3', 'weapsubtype3_txt', 'weaptype4', 'weaptype4_txt', 'weapsubtype4', 'weapsubtype4_txt',
    'weapdetail', 'nkillus', 'nkillter', 'nwoundus', 'nwoundte', 'propextent', 'propextent_txt',
    'propvalue', 'propcomment', 'nhostkid', 'nhostkidus', 'nhours', 'ndays', 'divert', 'kidhijcountry',
    'ransomamt', 'ransomamtus', 'ransompaid', 'ransompaidus', 'ransomnote', 'hostkidoutcome', 'hostkidoutcome_txt',
    'nreleased', 'addnotes', 'scite1', 'scite2', 'scite3', 'related','approxdate','extended','country','region','specificity','vicinity','crit1', 'crit2', 'crit3', 'doubtterr','multiple','natlty1_txt','guncertain1', 'guncertain2', 'guncertain3','nperps',
       'nperpcap','INT_LOG', 'INT_IDEO', 'INT_MISC', 'INT_ANY','attacktype1','property','weaptype1','resolution'],axis=1,inplace=True)   #droping unnecassary columns from the dataframe

# %%
Gterrorism_df.shape     #to check the columns after drop
# Out:
# (181691, 26)

# %%
Gterrorism_df.columns   #columns name in the dataframe
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'country_txt', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'alternative_txt',
#        'success', 'suicide', 'attacktype1_txt', 'targtype1_txt',
#        'targsubtype1_txt', 'gname', 'individual', 'claimed', 'weaptype1_txt',
#        'weapsubtype1_txt', 'nkill', 'nwound', 'ishostkid', 'ransom',
#        'dbsource'],
#       dtype='object')

# %% [markdown]
# **Renaming the colums**

# %%
Gterrorism_df.rename(columns={'eventid':'Event_ID','iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country',
       'region_txt':'Region', 'provstate':'Province_State', 'city':'City', 'latitude':'Latitude', 'longitude':'Longitude',
       'alternative_txt':'Alternative_Description', 'success':'Success', 'suicide':'Suicide', 'attacktype1_txt':'Attack_Type',
       'targtype1_txt':'Target_Type_Description', 'targsubtype1_txt':'Target_Subtype_Description', 'gname':'Group_Name', 'individual':'Individual_Attack', 'claimed':'Claimed',
       'weaptype1_txt':'Weapon_Type', 'weapsubtype1_txt':'Weapon_Subtype', 'nkill':'Fatalities', 'nwound':'Injured', 'ishostkid':'Hostages',
       'ransom':'Ransom', 'dbsource':'Data_Source'},inplace=True)

# %%
Gterrorism_df.columns   #to check the columns name after renaming it
# Out:
# Index(['Event_ID', 'Year', 'Month', 'Day', 'Country', 'Region',
#        'Province_State', 'City', 'Latitude', 'Longitude',
#        'Alternative_Description', 'Success', 'Suicide', 'Attack_Type',
#        'Target_Type_Description', 'Target_Subtype_Description', 'Group_Name',
#        'Individual_Attack', 'Claimed', 'Weapon_Type', 'Weapon_Subtype',
#        'Fatalities', 'Injured', 'Hostages', 'Ransom', 'Data_Source'],
#       dtype='object')

# %% [markdown]
# **Data Type Conversion**

# %%
Gterrorism_df.info()    #to get info about the columns's datatype
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 26 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Event_ID                    181691 non-null  int64
#  1   Year                        181691 non-null  int64
#  2   Month                       181691 non-null  int64
#  3   Day                         181691 non-null  int64
#  4   Country                     181691 non-null  object
#  5   Region                      181691 non-null  object
#  6   Province_State              181270 non-null  object
#  7   City                        181257 non-null  object
#  8   Latitude                    177135 non-null  float64
#  9   Longitude                   177134 non-null  float64
#  10  Alternative_Description     29011 non-null   object
#  11  Success                     181691 non-null  int64
#  12  Suicide                     181691 non-null  int64
# ...

# %%
columns_to_change = ['Success', 'Suicide', 'Individual_Attack', 'Claimed', 'Fatalities', 'Injured', 'Hostages', 'Ransom']   #converting some columns's datatype
Gterrorism_df[columns_to_change] = Gterrorism_df[columns_to_change].astype('object')

# %%
Gterrorism_df.info()     #to check the columns's datatype after conversion
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 26 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Event_ID                    181691 non-null  int64
#  1   Year                        181691 non-null  int64
#  2   Month                       181691 non-null  int64
#  3   Day                         181691 non-null  int64
#  4   Country                     181691 non-null  object
#  5   Region                      181691 non-null  object
#  6   Province_State              181270 non-null  object
#  7   City                        181257 non-null  object
#  8   Latitude                    177135 non-null  float64
#  9   Longitude                   177134 non-null  float64
#  10  Alternative_Description     29011 non-null   object
#  11  Success                     181691 non-null  object
#  12  Suicide                     181691 non-null  object
# ...

# %% [markdown]
# **Handling Missing Values**

# %%
Gterrorism_df.info()            #getting the info about the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 26 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Event_ID                    181691 non-null  int64
#  1   Year                        181691 non-null  int64
#  2   Month                       181691 non-null  int64
#  3   Day                         181691 non-null  int64
#  4   Country                     181691 non-null  object
#  5   Region                      181691 non-null  object
#  6   Province_State              181270 non-null  object
#  7   City                        181257 non-null  object
#  8   Latitude                    177135 non-null  float64
#  9   Longitude                   177134 non-null  float64
#  10  Alternative_Description     29011 non-null   object
#  11  Success                     181691 non-null  object
#  12  Suicide                     181691 non-null  object
# ...

# %%
# List of columns to fill missing values
columns_to_fill = ['Province_State','City','Longitude','Latitude', 'Alternative_Description', 'Target_Subtype_Description', 'Claimed', 'Weapon_Subtype', 'Fatalities', 'Injured', 'Hostages', 'Ransom']

# Fill missing values in specified columns with 'Unknown'
Gterrorism_df[columns_to_fill] = Gterrorism_df[columns_to_fill].fillna('Unknown')

# %%
Gterrorism_df.info()      #getting the info about the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 26 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Event_ID                    181691 non-null  int64
#  1   Year                        181691 non-null  int64
#  2   Month                       181691 non-null  int64
#  3   Day                         181691 non-null  int64
#  4   Country                     181691 non-null  object
#  5   Region                      181691 non-null  object
#  6   Province_State              181691 non-null  object
#  7   City                        181691 non-null  object
#  8   Latitude                    181691 non-null  object
#  9   Longitude                   181691 non-null  object
#  10  Alternative_Description     181691 non-null  object
#  11  Success                     181691 non-null  object
#  12  Suicide                     181691 non-null  object
# ...

# %% [markdown]
# **Data Manipulation**

# %% [markdown]
# **The 'Success' column in the DataFrame 'Gterrorism_df' was transformed by replacing values: 1 with 'Yes' and 0 with 'No'. This change enhances clarity, making the column's meaning more intuitive and easier to understand, aiding subsequent analyses or interpretations of the data.**

# %%
Gterrorism_df['Success'].value_counts()              #getting the value counts
# Out:
# 1    161632
# 0     20059
# Name: Success, dtype: int64

# %%
# Replace values in the 'Success' column
Gterrorism_df['Success'] = Gterrorism_df['Success'].replace({1: 'Yes', 0: 'No'})

# %%
Gterrorism_df['Success'].value_counts()                  #getting the value counts
# Out:
# Yes    161632
# No      20059
# Name: Success, dtype: int64

# %% [markdown]
# **In the DataFrame 'Gterrorism_df', the 'Suicide' column's values, where 0 denoted 'No Suicide' and 1 represented 'Suicide Involved', were transformed. This conversion provides a clearer understanding of suicide involvement, aiding data analysis by conveying this aspect more effectively.**

# %%
Gterrorism_df['Suicide'].value_counts()                #getting the value counts
# Out:
# 0    175058
# 1      6633
# Name: Suicide, dtype: int64

# %%
# Define a mapping for replacement
suicide_mapping = {
    0: 'No Suicide',
    1: 'Suicide Involved'
}

# Replace values in the 'Suicide' column
Gterrorism_df['Suicide'] = Gterrorism_df['Suicide'].replace(suicide_mapping)

# %%
Gterrorism_df['Suicide'].value_counts()               #getting the value counts
# Out:
# No Suicide          175058
# Suicide Involved      6633
# Name: Suicide, dtype: int64

# %% [markdown]
# **The 'Claimed' column in 'Gterrorism_df' underwent a comprehensive transformation. The mapping replacement assigned 'Claimed' to 0.0, 'Not Claimed' to 1.0, and 'Claim Data Unavailable' to both 'Unknown' and -9.0. This meticulous update enhances the column's meaning, providing valuable insights while handling missing or unclear data points.**

# %%
Gterrorism_df['Claimed'].unique()          #checking the unique values
# Out:
# array(['Unknown', 0.0, 1.0, -9.0], dtype=object)

# %%
# Define a mapping for replacement
claimed_mapping = {
    0.0: 'Claimed',
    1.0: 'Not Claimed',
    'Unknown':'Claim Data Unavailable',
    -9.0: 'Claim Data Unavailable'
}

# Replace values in the 'Claimed' column
Gterrorism_df['Claimed'] = Gterrorism_df['Claimed'].replace(claimed_mapping)

# %%
Gterrorism_df['Claimed'].unique()              #checking the unique values
# Out:
# array(['Claim Data Unavailable', 'Claimed', 'Not Claimed'], dtype=object)

# %% [markdown]
# **In the 'Hostages' column of 'Gterrorism_df', diverse values like 0.0, 1.0, 'Unknown', and -9.0 were replaced with meaningful descriptions. This transformation enhances data comprehension by assigning clear labels such as 'No Hostages', 'Hostages Taken'and 'Hostages Data Unavailable', enriching the dataset's interpretative value.**

# %%
Gterrorism_df['Hostages'].unique()               #checking the unique values
# Out:
# array([0.0, 1.0, 'Unknown', -9.0], dtype=object)

# %%
# Define a mapping for replacement
hostages_mapping = {
    0.0: 'No Hostages',
    1.0: 'Hostages Taken',
    'Unknown': 'Hostages Data Unavailable',
    -9.0: 'Hostages Data Unavailable'
}

# Replace values in the 'Hostages' column
Gterrorism_df['Hostages'] = Gterrorism_df['Hostages'].replace(hostages_mapping)

# %% [markdown]
# **In 'Gterrorism_df', the 'Ransom' column was updated to enhance data comprehension. 'Ransom Status Unknown' replaced 'Unknown', 'No Ransom' represented 0.0 occurrences, and 'Ransom Data Unavailable' encompassed both -9.0 and 1.0 entries. This transformation improves data interpretation, particularly in handling uncertain or missing ransom information.**

# %%
Gterrorism_df['Ransom'].value_counts()                  #checking the unique values
# Out:
# Unknown    104310
# 0.0         74684
# -9.0         1398
# 1.0          1299
# Name: Ransom, dtype: int64

# %%
# Define a mapping for replacement
ransom_mapping = {
    'Unknown': 'Ransom Status Unavailable',
    0.0: 'No Ransom',
    -9.0: 'Ransom Data Unavailable',
    1.0: 'Ransom Data Unavailable'
}

# Replace values in the 'Ransom' column
Gterrorism_df['Ransom'] = Gterrorism_df['Ransom'].replace(ransom_mapping)

# %% [markdown]
# **Replacing the invalid month values (0) with the mode (most frequent) month enhances data integrity by using a representative and appropriate categorical value, improving analysis accuracy.**

# %%
# Assuming Gterrorism_df is your DataFrame
mode_month = Gterrorism_df['Month'].mode().values[0]

# Replace 0 with the mode month value
Gterrorism_df['Month'] = Gterrorism_df['Month'].replace(0, mode_month)

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# During the process of data wrangling, several important steps were undertaken to prepare the dataset for analysis. These steps not only enhance the quality of the data but also facilitate a more meaningful exploration of the insights it contains.
#
# 1. **Column Removal:** The initial step involved the thoughtful removal of extraneous columns from the dataset. By eliminating columns that were deemed unnecessary for the analysis, the dataset was streamlined, allowing for a clearer focus on the key variables of interest.
#
# 2. **Column Renaming:** Recognizing the significance of clear and informative column names, a subsequent step entailed the renaming of columns to ensure they were in a more user-friendly format. Descriptive and well-formatted column names contribute significantly to the interpretability of the data and ease the subsequent analysis.
#
# 3. **Handling Missing Values:** Addressing missing values is crucial to prevent potential distortions in the analysis. In this regard, missing values were diligently handled by filling them with the value 'Unknown'. This approach acknowledges the absence of specific information while maintaining data integrity and continuity.
#
# 4. **Data Manipulation:** Selected columns underwent data manipulation, replacing existing values with more meaningful representations. This transformation enhances data clarity, making it more understandable and suitable for subsequent analyses.
#
# By conducting these data wrangling steps, the dataset was refined and made ready for insightful analysis. This process not only ensures data accuracy and consistency but also paves the way for a more robust understanding of the underlying trends and patterns within the data.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### 1.  What are the temporal trends in global terrorism over the last four decades?

# %%
Four_decades=Gterrorism_df['Year'].value_counts().sort_index()            #getting the value counts
Four_decades
# Out:
# 1970      651
# 1971      471
# 1972      568
# 1973      473
# 1974      581
# 1975      740
# 1976      923
# 1977     1319
# 1978     1526
# 1979     2662
# 1980     2662
# 1981     2586
# 1982     2544
# 1983     2870
# 1984     3495
# 1985     2915
# 1986     2860
# 1987     3183
# 1988     3721
# 1989     4324
# 1990     3887
# 1991     4683
# 1992     5071
# 1994     3456
# 1995     3081
# 1996     3058
# 1997     3197
# 1998      934
# 1999     1395
# 2000     1814
# 2001     1906
# 2002     1333
# 2003     1278
# 2004     1166
# 2005     2017
# 2006     2758
# 2007     3242
# 2008     4805
# 2009     4721
# 2010     4826
# 2011     5076
# 2012     8522
# 2013    12036
# 2014    16903
# 2015    14965
# 2016    13587
# 2017    10900
# Name: Year, dtype: int64

# %% [markdown]
# **Line Chart(Univariate)**

# %%
# Calculate the number of incidents per year
four_decades = Gterrorism_df['Year'].value_counts().sort_index()

# Create a line plot
plt.figure(figsize=(10, 6))
plt.plot(four_decades.index, four_decades.values, marker='o', linestyle='-', color='b')
plt.title('Temporal Trends in Global Terrorism (Last Four Decades)')
plt.xlabel('Year')
plt.ylabel('Number of Incidents')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I have created a line plot using the provided code and data to illustrate the temporal trends in global terrorism incidents over the last four decades. This choice of chart effectively visualizes changes in the number of incidents over time, aiding in the identification of patterns and trends within the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The line plot reveals insights into global terrorism trends over four decades. Notably, the early 2000s saw a marked surge in incidents, peaking around 2014, possibly linked to geopolitical events. Contrarily, recent years display a decline, suggesting counterterrorism efforts. The data hints at cyclical patterns and key turning points, reflecting global strategies and conflicts. The plot's extended timeframe offers a comprehensive perspective, emphasizing the impact of international events on terrorism. However, variations may also stem from evolving reporting methods. These insights underscore the complex interplay between global dynamics and terrorism, urging deeper analysis for a nuanced understanding.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights can potentially lead to a positive business impact by aiding risk assessment and strategic planning, helping businesses adapt to geopolitical shifts that could impact their operations. However, the insight of a surge in terrorism incidents around 2014 might lead to negative growth for industries reliant on stable global conditions, such as travel and tourism, as heightened security concerns could deter travelers.

# %% [markdown]
# ####2. Which region have experienced the highest frequency of terrorist attacks?

# %%
Region_terror=Gterrorism_df['Region'].value_counts()                           #getting the value counts
Region_terror
# Out:
# Middle East & North Africa     50474
# South Asia                     44974
# South America                  18978
# Sub-Saharan Africa             17550
# Western Europe                 16639
# Southeast Asia                 12485
# Central America & Caribbean    10344
# Eastern Europe                  5144
# North America                   3456
# East Asia                        802
# Central Asia                     563
# Australasia & Oceania            282
# Name: Region, dtype: int64

# %% [markdown]
# **Horizontal Bar Chart(Univariate)**

# %%
# Assuming you have a Series named Region_terror
labels = Region_terror.index
sizes = Region_terror.values

# Create a horizontal bar chart
plt.figure(figsize=(10, 8))
plt.barh(labels, sizes, color='skyblue')
plt.xlabel('Number of Incidents')
plt.ylabel('Region')
plt.title('Distribution of Terrorist Attacks by Region')

# Display the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The chosen horizontal bar chart effectively visualizes the distribution of terrorist attacks by region. Its horizontal layout makes it easy to compare the number of incidents across different regions. The clear labeling of regions on the y-axis and the corresponding incident counts on the x-axis provide a straightforward and impactful representation of the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart highlights the disparity in terrorist attack occurrences across various regions. The Middle East & North Africa, along with South Asia, experience the highest number of incidents, indicating ongoing security challenges. Conversely, Australasia & Oceania, Central Asia, and East Asia have notably lower incident counts. This visualization underscores the uneven geographical distribution of terrorism, emphasizing the need for focused security measures in highly affected regions.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights can help create a positive business impact. By identifying high-risk regions, businesses can implement targeted security measures and risk management strategies. However, negative growth might occur if businesses expand into regions with high terrorism rates without appropriate mitigation, potentially facing security issues, supply chain disruptions, and reputational damage, leading to economic setbacks.

# %% [markdown]
# #### 3. Which Top 10 countries have experienced the highest frequency of terrorist attacks?

# %%
top_countries=Gterrorism_df['Country'].value_counts().head(10)    #top 10 countries experienced the highest frequency of terrorist attcaks
top_countries
# Out:
# Iraq              24636
# Pakistan          14368
# Afghanistan       12731
# India             11960
# Colombia           8306
# Philippines        6908
# Peru               6096
# El Salvador        5320
# United Kingdom     5235
# Turkey             4292
# Name: Country, dtype: int64

# %%
Bottom_countries=Gterrorism_df['Country'].value_counts().tail(10)   #Bottom 10 countries experienced the highest frequency of terrorist attcaks
top_countries
Bottom_countries
# Out:
# Vatican City           1
# Falkland Islands       1
# St. Lucia              1
# North Korea            1
# New Hebrides           1
# International          1
# Wallis and Futuna      1
# South Vietnam          1
# Andorra                1
# Antigua and Barbuda    1
# Name: Country, dtype: int64

# %% [markdown]
# **Bar Chart(Univariate)**

# %%
# Create a bar chart
plt.figure(figsize=(10, 6))
top_countries.plot(kind='bar')
plt.title('Top Countries with Highest Frequency of Terrorist Attacks')
plt.xlabel('Country')
plt.ylabel('Number of Incidents')
plt.xticks(rotation=45)
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The Bar chart of countries with the highest terrorist attack frequencies offers businesses insights to assess risks, manage supply chains, plan finances, and adapt market entry strategies. However, industries tied to these regions, like tourism and trade, could experience negative growth due to heightened security concerns and instability.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insights from the analysis of both the top and bottom countries with the highest frequency of terrorist attacks are as follows:
#
# 1. **Disproportionate Impact**: The top countries, like Iraq, Pakistan, and Afghanistan, experience significantly higher incidents, highlighting persistent security challenges and instability.
#
# 2. **Negligible Impact**: The bottom countries, including Vatican City, Falkland Islands, and St. Lucia, have extremely low incident counts, indicating minimal terrorism concerns.
#
# 3. **Geopolitical Disparity**: The disparity between high-impact and low-impact countries underscores the complex nature of terrorism, with certain regions facing greater vulnerabilities.
#
# 4. **Resource Allocation**: Organizations can allocate resources and strategies based on the varying levels of terrorism threat across different countries.
#
# 5. **Global Variances**: Terrorism's impact varies widely, and businesses need tailored approaches for risk management and security based on their operational regions.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights can lead to a positive business impact by aiding risk assessment, security planning, and informed decisions. High-impact countries might require enhanced security measures, while low-impact ones can benefit from streamlined strategies. However, negative growth could occur if businesses heavily tied to high-impact regions face security-related disruptions or if expansion plans are hindered due to perceived risks.

# %% [markdown]
# #### 4. Which Top 10 cities have experienced the highest frequency of terrorist attacks?

# %%
Gterrorism_df['City'].value_counts().head(10)                     #getting the value counts
# Out:
# Unknown         10209
# Baghdad          7589
# Karachi          2652
# Lima             2359
# Mosul            2265
# Belfast          2171
# Santiago         1621
# Mogadishu        1581
# San Salvador     1558
# Istanbul         1048
# Name: City, dtype: int64

# %% [markdown]
# **Pie Chart(Univariate)**

# %% [markdown]
# **Note->The top cities with the highest terrorist attack counts, excluding "Unknown" are Baghdad (7589), Karachi (2652), Lima (2359), Mosul (2265), Belfast (2171), Santiago (1621), Mogadishu (1581), San Salvador (1558), and Istanbul (1048)**

# %%
#This code uses a dictionary to define the top cities and their corresponding attack counts (excluding "Unknown")
city_counts = {
    'Baghdad': 7589,
    'Karachi': 2652,
    'Lima': 2359,
    'Mosul': 2265,
    'Belfast': 2171,
    'Santiago': 1621,
    'Mogadishu': 1581,
    'San Salvador': 1558,
    'Istanbul': 1048
}

cities = list(city_counts.keys())
attack_counts = list(city_counts.values())

plt.figure(figsize=(8, 8))
plt.pie(attack_counts, labels=cities, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
plt.title('Distribution of Terrorist Attacks in Top Cities')

plt.axis('equal')  # Equal aspect ratio ensures the pie chart is circular.

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The chosen pie chart is apt for representing the distribution of terrorist attacks in the top cities (excluding "Unknown"). It effectively shows the proportional contribution of each city to the total incidents. This visualization simplifies comparison and highlights the most significant cities in terms of attack occurrences.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The pie chart reveals the varying degrees of terrorist attack occurrences across the top cities, excluding "Unknown." Baghdad and Karachi stand out as the most affected cities, while others exhibit relatively lower incident frequencies. This visualization underscores the concentrated nature of terrorism incidents within a few specific urban areas.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights can help businesses enhance security measures in high-risk cities, safeguarding assets and personnel. However, potential negative growth might result if businesses neglect security considerations, risking disruptions, financial losses, and reputational harm in vulnerable locations.

# %% [markdown]
# ####5. What are the most common types of terrorist tactics employed during the studied period?

# %%
common_attack_types=Gterrorism_df['Attack_Type'].value_counts().head()                    #getting the value counts
common_attack_types
# Out:
# Bombing/Explosion                 88255
# Armed Assault                     42669
# Assassination                     19312
# Hostage Taking (Kidnapping)       11158
# Facility/Infrastructure Attack    10356
# Name: Attack_Type, dtype: int64

# %% [markdown]
# **Bar Chart(Univariate)**

# %%
common_attack_types = Gterrorism_df['Attack_Type'].value_counts().head()    #code for data visualisation
plt.figure(figsize=(10, 6))
common_attack_types.plot(kind='bar', color='skyblue')
plt.xlabel('Attack Type')
plt.ylabel('Frequency')
plt.title('Most Common Types of Terrorist Tactics')
plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The chosen bar chart effectively displays the frequency of the most common terrorist tactics. Its simplicity and clear labeling make it easy to compare attack types and their occurrence. The rotated x-axis labels accommodate longer attack type names, enhancing readability and ensuring the chart conveys insights comprehensively.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insights reveal that bombings/explosions are the most common terrorist tactics, followed by armed assaults and assassinations. This suggests a focus on widespread impact and confrontation, underlining the significance of violence and strategic targeting in these incidents.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights can aid businesses in assessing potential threats and enhancing security measures in high-risk areas. However, a negative impact might arise if businesses are located in regions frequently targeted by bombings or armed assaults. Such incidents can lead to disruptions, harm to employees, and damage to infrastructure, affecting operations and reputation, ultimately resulting in negative growth prospects for those businesses.

# %% [markdown]
# ####6. Are there any seasonal or cyclical patterns in terrorist activity?

# %%
Gterrorism_df['Month'].value_counts()                         #getting the value counts
# Out:
# 5     16895
# 7     16268
# 8     15800
# 10    15563
# 6     15359
# 3     15257
# 4     15152
# 1     14936
# 11    14906
# 9     14180
# 2     13879
# 12    13496
# Name: Month, dtype: int64

# %% [markdown]
# **Line Chart(Univariate)**

# %%
# Month names for labeling the x-axis
month_names = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# Frequencies of attacks for each month
attack_counts = [14936, 13879, 15257, 15152, 16895, 15359, 16268, 15800, 14180, 15563, 14906, 13496]

plt.figure(figsize=(10, 6))
plt.plot(month_names, attack_counts, marker='o', color='skyblue')
plt.xlabel('Month')
plt.ylabel('Frequency')
plt.title('Terrorist Activity by Month')
plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The selected line plot is suitable for showing seasonal or cyclical patterns in data. It effectively displays changes in terrorist activity over months, making trends and variations easy to identify. The use of markers helps pinpoint individual months, while the line aids in visualizing the overall trend.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The line plot reveals insights into the temporal distribution of terrorist activity:
#
# 1. **Seasonal Variation**: There appears to be a pattern of increased terrorist activity during certain months, such as May, July, and August, suggesting potential seasonal trends in attacks.
#
# 2. **Potential Cycles**: The plot suggests cyclic patterns, with fluctuations occurring across the months. This could imply a recurring nature of terrorist incidents over time.
#
# 3. **Lower Activity in Winter**: Some winter months, like December and January, seem to exhibit relatively lower attack frequencies.
#
# The visualization highlights potential seasonality and cyclical behavior in terrorist activity, which can aid in understanding and predicting patterns of incidents.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights can indeed create a positive business impact. By understanding the seasonal and cyclical patterns in terrorist activity, businesses can implement targeted security measures during high-risk periods, safeguarding assets and personnel. However, the potential for negative growth arises if businesses neglect to adjust their operations and security strategies based on these patterns. Failure to adapt could expose businesses to higher risks, leading to disruptions, financial losses, and reputational damage.

# %% [markdown]
# ####7. How have terrorist attack patterns evolved over time in different regions?

# %% [markdown]
# **Line Chart(Bivariate)**

# %%
#data visualisation code
plt.figure(figsize=(12, 8))
attack_patterns = Gterrorism_df.groupby(['Year', 'Region']).size().unstack()

# Plotting each region's attack pattern using a line plot
for region in attack_patterns.columns:
    plt.plot(attack_patterns.index, attack_patterns[region], label=region)

plt.xlabel('Year')
plt.ylabel('Number of Attacks')
plt.title('Terrorist Attack Patterns Over Time in Different Regions')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The heatmap provides a comprehensive overview of how terrorist attack patterns have evolved across different regions over time. It enables easy comparison and identification of trends and changes, facilitating a quick grasp of historical variations in each region's security landscape.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The heatmap depicts evolving terrorist attack patterns across regions and time. It highlights shifts in hotspots, consistent challenges in areas like South Asia, Sub-Saharan Africa, and the Middle East, and varying intensities over decades. These insights enable targeted security strategies, global trend analysis, and informed decision-making to address dynamic security threats.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights can indeed foster a positive business impact. Enhanced understanding of evolving attack patterns allows businesses to adapt security measures effectively, safeguarding assets and personnel. However, regions with persistent high activity might pose challenges for business operations and investments due to potential instability, potentially leading to negative growth in those areas.

# %% [markdown]
# ####8.Analyze the occurrence of different attack types across various regions to uncover patterns in the geographical distribution of terrorist tactics?

# %%
attack_type_region_freq = Gterrorism_df.groupby(['Attack_Type', 'Region']).size().reset_index(name='Frequency')           #using groupby method
print(attack_type_region_freq)
# Out:
#        Attack_Type                       Region  Frequency
# 0    Armed Assault        Australasia & Oceania         51
# 1    Armed Assault  Central America & Caribbean       4361
# 2    Armed Assault                 Central Asia        116
# 3    Armed Assault                    East Asia        117
# 4    Armed Assault               Eastern Europe       1274
# ..             ...                          ...        ...
# 103        Unknown                South America        754
# 104        Unknown                   South Asia       2021
# 105        Unknown               Southeast Asia        433
# 106        Unknown           Sub-Saharan Africa       1355
# 107        Unknown               Western Europe        265
#
# [108 rows x 3 columns]

# %% [markdown]
# **Bar Chart(Bivariate)**

# %%
sns.set(style="whitegrid")      #data visualisation code
plt.figure(figsize=(12, 8))

filtered_df = Gterrorism_df[Gterrorism_df['Attack_Type'] != 'Unknown']
sns.countplot(data=filtered_df, x='Attack_Type', hue='Region', order=filtered_df['Attack_Type'].value_counts().index)
plt.xticks(rotation=45)
plt.xlabel('Attack Type')
plt.ylabel('Frequency')
plt.title('Frequency of Attack Types across Regions')
plt.legend(title='Region')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The chosen chart, a clustered bar chart with hue grouping by region, effectively visualizes the frequency distribution of different attack types across various regions. It allows for easy comparison of attack types within each region while also providing a clear comparison across regions. The hue grouping enhances the chart's comprehensibility by differentiating regions visually.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart illustrates that "Bombing/Explosion" is the most common attack type across most regions. In "South Asia," "Armed Assault" is notable. Additionally, the "Middle East & North Africa" region sees a significant frequency of "Hostage Taking" compared to other regions.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights can help create a positive impact by aiding businesses in understanding the security landscape across regions. Negative impact may arise if a business operates in a region with higher "Hostage Taking" incidents, potentially affecting employee safety and business continuity.

# %% [markdown]
# ####9.What are the primary target types of terrorist attacks recorded?

# %%
Primary_target_type=Gterrorism_df['Target_Type_Description'].value_counts()                 #getting the value counts
Primary_target_type
# Out:
# Private Citizens & Property       43511
# Military                          27984
# Police                            24506
# Government (General)              21283
# Business                          20669
# Transportation                     6799
# Utilities                          6023
# Unknown                            5898
# Religious Figures/Institutions     4440
# Educational Institution            4322
# Government (Diplomatic)            3573
# Terrorists/Non-State Militia       3039
# Journalists & Media                2948
# Violent Political Party            1866
# Airports & Aircraft                1343
# Telecommunication                  1009
# NGO                                 970
# Tourists                            440
# Maritime                            351
# Food or Water Supply                317
# Abortion Related                    263
# Other                               137
# Name: Target_Type_Description, dtype: int64

# %% [markdown]
# **Bar Chart(Univariate)**

# %%
plt.figure(figsize=(12, 8))   #data visualisation code
Primary_target_type.plot(kind='bar', color='skyblue')
plt.xlabel('Frequency')
plt.ylabel('Target Type')
plt.title('Frequency of Target Types')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The chosen bar chart effectively displays the frequency distribution of various target types. With the x-axis representing frequency and the y-axis showing target types, it allows quick comparison and identification of the most common target types, aiding clear insights into the data's distribution.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals that "Private Citizens & Property," "Military," and "Police" are the most frequently targeted types. These insights can guide security measures and resource allocation for businesses and organizations. It's also evident that some target types, like "Other" and "Abortion Related," have notably lower frequencies.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights can contribute to a positive business impact by aiding companies in understanding the most vulnerable target types and enhancing security measures accordingly. Lower-frequency targets like "Other" may need less attention, while high-frequency targets require more protection.

# %% [markdown]
# ####10.What are the most frequent weapons used in terrorist attacks?

# %%
Gterrorism_df['Weapon_Type'].value_counts()                           #getting the value counts
# Out:
# Explosives                                                                     92426
# Firearms                                                                       58524
# Unknown                                                                        15157
# Incendiary                                                                     11135
# Melee                                                                           3655
# Chemical                                                                         321
# Sabotage Equipment                                                               141
# Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)      136
# Other                                                                            114
# Biological                                                                        35
# Fake Weapons                                                                      33
# ...

# %%
Frequent_weapon=Gterrorism_df[Gterrorism_df['Weapon_Type'] != 'Unknown']            #getting the value counts
x=Frequent_weapon['Weapon_Type'].value_counts()
x
# Out:
# Explosives                                                                     92426
# Firearms                                                                       58524
# Incendiary                                                                     11135
# Melee                                                                           3655
# Chemical                                                                         321
# Sabotage Equipment                                                               141
# Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)      136
# Other                                                                            114
# Biological                                                                        35
# Fake Weapons                                                                      33
# Radiological                                                                      14
# Name: Weapon_Type, dtype: int64

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a horizontal bar chart because it efficiently presents the frequency distribution of weapon types. The horizontal orientation allows for clear comparison and easy identification of the most common weapon types.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals insights into the prevalence of weapon types in terrorism incidents. "Explosives" and "Firearms" are the most frequently used weapons. While conventional weapons like "Melee" are present, "Chemical," "Sabotage Equipment," and "Radiological" are relatively rare. This information can guide counter-terrorism efforts by prioritizing resources and strategies based on the prevalence of weapon types.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights can positively impact businesses by enhancing security measures and risk management strategies. However, if businesses operate in regions where weapons like "Chemical" or "Radiological" are used, the potential for severe incidents may lead to negative growth due to heightened security costs, reputational damage, and potential disruption of operations.

# %% [markdown]
# ####11. Is there a correlation between the target type and the attack type?

# %% [markdown]
# **Bar Chart(Bivariate)**

# %%
# Assuming Gterrorism_df is your DataFrame
pivot_table = pd.crosstab(
    Gterrorism_df['Target_Type_Description'],
    Gterrorism_df['Attack_Type']
)

plt.figure(figsize=(12, 8))

pivot_table.plot(kind='bar', figsize=(12, 8))
plt.xlabel('Target Type')
plt.ylabel('Count')
plt.title('Correlation between Target Types and Attack Types')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Attack Type')
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a grouped bar chart as it effectively illustrates the relationship between target types and attack types. It enables easy comparison and visual identification of patterns, aiding in understanding their correlation.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals how different attack types are distributed among various target types, offering insights into their correlation and frequency.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights can positively impact businesses by aiding security measures and resource allocation. High attack frequency on specific target types might prompt heightened protection. However, insights revealing vulnerabilities could lead to negative growth due to potential security costs and reputational damage.

# %% [markdown]
# ####12.To identify and analyze the terrorist group with the highest top 5 contribution in terrorist?

# %%
Gterrorism_df[Gterrorism_df['Group_Name'] != 'Unknown']['Group_Name'].value_counts().head(5)            #getting the value counts
# Out:
# Taliban                                             7478
# Islamic State of Iraq and the Levant (ISIL)         5613
# Shining Path (SL)                                   4555
# Farabundo Marti National Liberation Front (FMLN)    3351
# Al-Shabaab                                          3288
# Name: Group_Name, dtype: int64

# %% [markdown]
# **Pie Chart(Univariate)**

# %%
top_groups = Gterrorism_df[Gterrorism_df['Group_Name'] != 'Unknown']['Group_Name'].value_counts().head(5)         #data visualisation code
plt.figure(figsize=(8, 8))
plt.pie(top_groups, labels=top_groups.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
plt.title('Top 5 Terrorist Groups (Excluding "Unknown")')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a pie chart to display the distribution of the top 5 terrorist groups. The pie chart effectively showcases the relative proportions of these groups, aiding quick visual comparison and understanding of their significance in the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart presents insights into the most active terrorist groups. The "Taliban" stands out as the highest, followed by "Islamic State of Iraq and the Levant (ISIL)," "Shining Path (SL)," "Farabundo Marti National Liberation Front (FMLN)," and "Al-Shabaab." This information helps focus counter-terrorism efforts on these groups to enhance security measures.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights can positively impact businesses by enabling them to assess security risks in regions affected by these active terrorist groups. Businesses can take preventive measures, potentially avoiding disruptions and ensuring the safety of their operations and personnel. However, if the presence of these groups indicates increased instability, it could lead to negative growth due to reduced investments and market uncertainties.

# %% [markdown]
# ####13. What is the proportion of successful terrorist attacks compared to failed ones using the 'success' variable?

# %%
success_rate=Gterrorism_df['Success'].value_counts()                        #getting the value counts
success_rate
# Out:
# Yes    161632
# No      20059
# Name: Success, dtype: int64

# %% [markdown]
# **Pie Chart(Univariate)**

# %%
#Data Visualisation Code
plt.figure(figsize=(6, 6))
success_rate.plot(kind='pie', autopct='%1.1f%%', startangle=140, colors=['brown', 'red'])
plt.title('Proportion of Successful vs. Failed Terrorist Attacks')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose the pie chart because it effectively represents the proportion of successful and failed terrorist attacks as distinct slices of a circle. Its visual simplicity and the ability to display percentages directly on the chart make it suitable for comparing two categories in a single visualization.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The pie chart illustrates that a significant majority of the terrorist attacks (around 89%) were successful, while the remaining 11% resulted in failure. This highlights the relatively higher frequency of successful attacks compared to unsuccessful ones in the dataset.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insight about the majority of successful terrorist attacks is crucial for security and risk management sectors. However, it could negatively impact tourism and investments in areas prone to attacks, affecting economic growth due to safety concerns. The business impact varies depending on the industry and context.

# %% [markdown]
# ####14. Correlation Heatmap

# %%
Gterrorism_df.corr()            #checking the correlation between the columns
# Out:
# <ipython-input-90-e6ac63d58bf8>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Gterrorism_df.corr()
#           Event_ID      Year     Month       Day
# Event_ID  1.000000  0.999996  0.002389  0.018336
# Year      0.999996  1.000000 -0.000178  0.018254
# Month     0.002389 -0.000178  1.000000  0.005212
# Day       0.018336  0.018254  0.005212  1.000000

# %% [markdown]
# **Heatmap(Multi-Variate)**

# %%
# Calculate correlation matrix
corr_matrix = Gterrorism_df.corr()

# Create a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Correlation Heatmap')
plt.show()
# Out:
# <ipython-input-91-0747f18e6bf2>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = Gterrorism_df.corr()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I suggested a correlation heatmap chart because it visually presents the relationships between numerical variables. This aids in identifying patterns, strengths, and directions of correlations within the dataset. The heatmap's color-coding enhances quick interpretation of positive, negative, or negligible correlations, facilitating data exploration and insights.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The provided correlation matrix suggests extremely high correlations (close to 1) between 'Event_ID' and 'Year', indicating their near-linear relationship due to both being time-related. Other correlations are negligible, indicating little or no linear relationships among 'Month', 'Day', and the other variables in the dataset.

# %% [markdown]
# ####15. Pair Plot

# %% [markdown]
# **Pair Plot(Multi-Variate)**

# %%
# Select numerical columns for the pair plot
numerical_columns = ['Year', 'Month', 'Day', 'Fatalities', 'Injured', 'Hostages']

# Create a pair plot
sns.pairplot(Gterrorism_df[numerical_columns])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I recommended a pair plot as it offers a comprehensive view of pairwise relationships between numerical variables in a dataset. It aids in identifying trends, patterns, and potential correlations, facilitating insights into how variables interact and potentially influence each other, fostering exploratory data analysis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The plot displays numerical variables, insights might include identifying correlations, trends, or potential outliers. These visual patterns could offer valuable information about the data's behavior and relationships between variables.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Based on the insights derived from the Global Terrorism Database (GTD) analysis, here are some recommendations for the client to achieve their business objectives:
#
# 1. **Targeted Security Measures**: Implement enhanced security measures in regions with a high frequency of terrorist incidents, such as the Middle East & North Africa and South Asia, while remaining vigilant in areas with lower incident counts.
#
# 2. **Strategic Resource Allocation**: Allocate resources and strategies based on the prevalent terrorist tactics, with a particular focus on countering bombings/explosions, armed assaults, and assassinations.
#
# 3. **Seasonal Preparedness**: Recognize and prepare for potential seasonal trends in terrorist activity, ensuring heightened vigilance during months like May, July, and August while also addressing the underlying reasons behind these patterns.
#
# 4. **Cyclical Analysis**: Further investigate the cyclic patterns observed in the temporal distribution of attacks, identifying the factors driving these cycles and using the insights to enhance counterterrorism strategies.
#
# 5. **Global Collaboration**: Collaborate with international organizations and governments to address the concentrated nature of terrorist incidents in certain cities and regions, encouraging information sharing and coordinated efforts.
#
# 6. **Localized Measures**: Tailor security strategies to address the specific target types prevalent in each region, adapting approaches to protect private citizens, military personnel, and police forces.
#
# 7. **Targeted Counter-Radicalization**: Leverage insights from the most active terrorist groups to design targeted counter-radicalization initiatives aimed at discouraging individuals from joining organizations like the Taliban, ISIL, and Al-Shabaab.
#
# 8. **Success-Failure Analysis**: Investigate the reasons behind the relatively higher success rate of terrorist attacks and focus on strategies that can disrupt the planning and execution of attacks, leading to a higher percentage of failures.
#
# 9. **Long-Term Patterns**: Analyze the extended timeframe of terrorism trends to identify historical turning points and correlate them with geopolitical events, enabling a deeper understanding of the impact of global dynamics on terrorism.
#
# 10. **Risk Management for Businesses**: Provide businesses operating in regions with higher terrorism risks with data-driven risk management strategies, facilitating informed decisions for their operations.
#
# 11. **Public Awareness Campaigns**: Utilize the findings to create impactful public awareness campaigns that educate the general population about terrorism's complexities and the need for ongoing efforts to combat it.
#
# 12. **Policy Recommendations**: Collaborate with policymakers to develop evidence-based counterterrorism policies, utilizing the insights to address the vulnerabilities in high-impact regions and refine existing strategies.
#
# 13. **Continuous Evaluation**: Establish a framework for evaluating the effectiveness of counterterrorism efforts, ensuring a continuous feedback loop to refine strategies and adapt to evolving threat landscapes.
#
# 14. **International Research Collaboration**: Foster collaboration with the global research community by sharing insights and analysis from the GTD, contributing to a comprehensive understanding of terrorism's multifaceted nature.
#
# 15. **Holistic Approach**: Recognize the interconnectedness of terrorism with global events, socio-political dynamics, and regional challenges, advocating for a holistic approach that considers all these factors in counterterrorism strategies.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# In conclusion, the analysis of the Global Terrorism Database (GTD) offers profound insights into the intricate world of terrorism, shedding light on patterns, trends, and correlations that have far-reaching implications for security, policy-making, and global collaboration. The comprehensive examination of the data has provided actionable recommendations for achieving the outlined business objectives.The analysis underscores the urgency of targeted security measures in regions with high incident frequencies, emphasizing the need for adaptable strategies that align with prevalent terrorist tactics. The identification of seasonal and cyclical patterns offers a valuable tool for anticipating and preparing for potential spikes in terrorist activity, while localized insights guide efforts to safeguard vulnerable target types.
# Moreover, the revelation of key terrorist groups and their activities serves as a foundation for tailored counter-radicalization initiatives, contributing to the broader goal of preventing recruitment and radicalization. The success-failure analysis highlights the significance of disruption in attack planning, further motivating resource allocation and collaboration to thwart future incidents.
# This analysis also underscores the importance of international cooperation in counterterrorism. By sharing knowledge, insights, and strategies, countries can collectively address the concentrated nature of incidents in specific cities and regions, fostering a global network committed to combating terrorism's evolving challenges.
#
# As we reflect on the insights derived from the GTD analysis, it's evident that addressing terrorism demands a multi-faceted approach that accounts for historical, seasonal, and cyclical dynamics. By embracing data-driven decision-making, fostering collaboration, and prioritizing the safety of citizens and organizations, the pursuit of the outlined business objectives stands poised to contribute significantly to a safer and more secure global landscape. The complexities revealed by this analysis reinforce the need for continuous evaluation, adaptable strategies, and a commitment to countering terrorism through holistic and informed efforts.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
